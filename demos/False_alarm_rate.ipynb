# %%
import bilby
import os
import glob
import numpy as np
from scipy import interpolate
import utilizes_plot
import corner.corner
import scienceplots
import matplotlib as mpl
import matplotlib.lines as mlines
import matplotlib.pyplot as plt
mpl.rcParams['font.family'] = ['serif']
mpl.rcParams['font.serif'] = ['Times New Roman']
# %matplotlib inline
plt.style.use(['science','ieee','no-latex'])

# %%
lnbf2g = np.loadtxt('lnbf2g.txt')

plt.style.use(['science','ieee','no-latex'])
plt.grid(which='major',linestyle='--',lw=0.2,alpha=0.8)

plt.hist(-1*lnbf2g,density=True,histtype='step',bins=14)
plt.xlabel(r'$\rm lnBF^{TOP}_{2G}$')
plt.ylabel(r'$\rm Probability\, density$')
plt.vlines(x=5.91,ymin=0,ymax=0.094,color='red',ls='--',lw=0.8)
plt.ylim(0,0.091)
plt.savefig('/home/yzq/Documents/nat_code_data/figures/false_alarm.pdf')
